# %%
#Import dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import timeit
from citipy import citipy
# Import the requests library.
import requests
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
    
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 745

# %%
# Import the API key.
from config import weather_api_key

# %% [markdown]
# ### City Weather Data for 500 cities

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key


# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")
# Create counters.
record_count = 1
set_count = 1


# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        #time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
    
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Course Description":city_description
                          })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | auki
# Processing Record 2 of Set 1 | hobart
# Processing Record 3 of Set 1 | port alfred
# Processing Record 4 of Set 1 | chokurdakh
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | vila velha
# Processing Record 7 of Set 1 | den helder
# Processing Record 8 of Set 1 | new norfolk
# Processing Record 9 of Set 1 | airai
# Processing Record 10 of Set 1 | albany
# Processing Record 11 of Set 1 | kodiak
# Processing Record 12 of Set 1 | atuona
# Processing Record 13 of Set 1 | quatre cocos
# Processing Record 14 of Set 1 | tasiilaq
# Processing Record 15 of Set 1 | ankang
# Processing Record 16 of Set 1 | ushuaia
# Processing Record 17 of Set 1 | port macquarie
# Processing Record 18 of Set 1 | port moresby
# Processing Record 19 of Set 1 | poso
# Processing Record 20 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 21 of Set 1 | butaritari
# Processing Record 22 of Set 1 | busselton
# Processing Record 23 of Set 1 | cape town
# Processing Record 24 of Set 1 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 25 of Set 1 | ancud
# Processing Record 26 of Set 1 | arraial do cabo
# Processing Record 27 of Set 1 | dalvik
# Processing Record 28 of Set 1 | beringovskiy
# Processing Record 29 of Set 1 | avarua
# Processing Record 30 of Set 1 | mataura
# Processing Record 31 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 32 of Set 1 | ishigaki
# Processing Record 33 of Set 1 | lillehammer
# Processing Record 34 of Set 1 | rio gallegos
# Processing Record 35 of Set 1 | san patricio
# Processing Record 36 of Set 1 | tigil
# Processing Record 37 of Set 1 | tessalit
# Processing Record 38 of Set 1 | port blair
# Processing Record 39 of Set 1 | namibe
# Processing Record 40 of Set 1 | vaini
# Processing Record 41 of Set 1 | faya
# Processing Record 42 of Set 1 | khatanga
# Processing Record 43 of Set 1 | qaanaaq
# Processing Record 44 of Set 1 | letcani
# Processing Record 45 of Set 1 | pietersburg
# Processing Record 46 of Set 1 | sitka
# Processing Record 47 of Set 1 | nuuk
# Processing Record 48 of Set 1 | acapulco
# Processing Record 49 of Set 1 | shakawe
# Processing Record 50 of Set 1 | bluff
# Processing Record 1 of Set 2 | salinas
# Processing Record 2 of Set 2 | esperance
# Processing Record 3 of Set 2 | punta arenas
# Processing Record 4 of Set 2 | henties bay
# Processing Record 5 of Set 2 | vallenar
# Processing Record 6 of Set 2 | xuddur
# Processing Record 7 of Set 2 | orange cove
# Processing Record 8 of Set 2 | camacha
# Processing Record 9 of Set 2 | mehamn
# Processing Record 10 of Set 2 | omboue
# Processing Record 11 of Set 2 | cortez
# Processing Record 12 of Set 2 | mar del plata
# Processing Record 13 of Set 2 | puerto ayora
# Processing Record 14 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 15 of Set 2 | victoria
# Processing Record 16 of Set 2 | salalah
# Processing Record 17 of Set 2 | sinnamary
# Processing Record 18 of Set 2 | maniitsoq
# Processing Record 19 of Set 2 | chumikan
# Processing Record 20 of Set 2 | lavrentiya
# Processing Record 21 of Set 2 | georgetown
# Processing Record 22 of Set 2 | kautokeino
# Processing Record 23 of Set 2 | sakakah
# Processing Record 24 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 25 of Set 2 | bolungarvik
# City not found. Skipping...
# Processing Record 26 of Set 2 | kapaa
# Processing Record 27 of Set 2 | cidreira
# Processing Record 28 of Set 2 | cherskiy
# Processing Record 29 of Set 2 | tuatapere
# Processing Record 30 of Set 2 | iqaluit
# Processing Record 31 of Set 2 | hermanus
# Processing Record 32 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 33 of Set 2 | narsaq
# Processing Record 34 of Set 2 | thompson
# Processing Record 35 of Set 2 | bathsheba
# Processing Record 36 of Set 2 | provideniya
# Processing Record 37 of Set 2 | nyrob
# Processing Record 38 of Set 2 | lokoja
# Processing Record 39 of Set 2 | samarai
# Processing Record 40 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 41 of Set 2 | ozinki
# Processing Record 42 of Set 2 | jamestown
# Processing Record 43 of Set 2 | bredasdorp
# Processing Record 44 of Set 2 | atar
# Processing Record 45 of Set 2 | novovasylivka
# Processing Record 46 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 47 of Set 2 | oktyabrskoye
# Processing Record 48 of Set 2 | mackenzie
# Processing Record 49 of Set 2 | eskilstuna
# Processing Record 50 of Set 2 | dosso
# Processing Record 1 of Set 3 | kruisfontein
# Processing Record 2 of Set 3 | jasper
# Processing Record 3 of Set 3 | chapais
# Processing Record 4 of Set 3 | horn lake
# Processing Record 5 of Set 3 | los llanos de aridane
# Processing Record 6 of Set 3 | oksfjord
# Processing Record 7 of Set 3 | port lincoln
# Processing Record 8 of Set 3 | pitimbu
# Processing Record 9 of Set 3 | carnarvon
# Processing Record 10 of Set 3 | ekhabi
# Processing Record 11 of Set 3 | faanui
# Processing Record 12 of Set 3 | vardo
# Processing Record 13 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 14 of Set 3 | kloulklubed
# Processing Record 15 of Set 3 | olafsvik
# Processing Record 16 of Set 3 | dire dawa
# Processing Record 17 of Set 3 | novikovo
# Processing Record 18 of Set 3 | coquimbo
# Processing Record 19 of Set 3 | hasanpur
# Processing Record 20 of Set 3 | teteven
# Processing Record 21 of Set 3 | gimli
# Processing Record 22 of Set 3 | ilulissat
# Processing Record 23 of Set 3 | upernavik
# Processing Record 24 of Set 3 | aykhal
# Processing Record 25 of Set 3 | saint-philippe
# Processing Record 26 of Set 3 | noumea
# Processing Record 27 of Set 3 | kralendijk
# Processing Record 28 of Set 3 | hobyo
# Processing Record 29 of Set 3 | tura
# Processing Record 30 of Set 3 | isabela
# Processing Record 31 of Set 3 | tuktoyaktuk
# Processing Record 32 of Set 3 | shingu
# Processing Record 33 of Set 3 | tilichiki
# Processing Record 34 of Set 3 | tual
# Processing Record 35 of Set 3 | sola
# Processing Record 36 of Set 3 | mogadishu
# Processing Record 37 of Set 3 | kefalos
# Processing Record 38 of Set 3 | smithers
# Processing Record 39 of Set 3 | kaitangata
# Processing Record 40 of Set 3 | ixtapa
# Processing Record 41 of Set 3 | hithadhoo
# Processing Record 42 of Set 3 | dubai
# Processing Record 43 of Set 3 | vila franca do campo
# Processing Record 44 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 45 of Set 3 | san pedro
# Processing Record 46 of Set 3 | howard springs
# Processing Record 47 of Set 3 | pevek
# Processing Record 48 of Set 3 | mandawar
# Processing Record 49 of Set 3 | mahebourg
# Processing Record 50 of Set 3 | castro
# Processing Record 1 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 2 of Set 4 | totma
# Processing Record 3 of Set 4 | bambous virieux
# Processing Record 4 of Set 4 | dikson
# Processing Record 5 of Set 4 | hilo
# Processing Record 6 of Set 4 | hasaki
# Processing Record 7 of Set 4 | sidi ali
# Processing Record 8 of Set 4 | broken hill
# Processing Record 9 of Set 4 | tidore
# City not found. Skipping...
# Processing Record 10 of Set 4 | rawannawi
# City not found. Skipping...
# Processing Record 11 of Set 4 | anamur
# Processing Record 12 of Set 4 | leshukonskoye
# Processing Record 13 of Set 4 | dutlwe
# Processing Record 14 of Set 4 | gorontalo
# Processing Record 15 of Set 4 | longyearbyen
# Processing Record 16 of Set 4 | boguchany
# Processing Record 17 of Set 4 | hamilton
# Processing Record 18 of Set 4 | yellowknife
# Processing Record 19 of Set 4 | dunedin
# Processing Record 20 of Set 4 | fairbanks
# Processing Record 21 of Set 4 | goundi
# Processing Record 22 of Set 4 | saran
# Processing Record 23 of Set 4 | ribeira grande
# Processing Record 24 of Set 4 | drochia
# Processing Record 25 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 26 of Set 4 | kalabo
# Processing Record 27 of Set 4 | mount gambier
# Processing Record 28 of Set 4 | arlit
# Processing Record 29 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 30 of Set 4 | bramming
# Processing Record 31 of Set 4 | yar-sale
# Processing Record 32 of Set 4 | neuquen
# Processing Record 33 of Set 4 | aloleng
# Processing Record 34 of Set 4 | ostrovnoy
# Processing Record 35 of Set 4 | torbat-e jam
# Processing Record 36 of Set 4 | inhambane
# Processing Record 37 of Set 4 | nyurba
# Processing Record 38 of Set 4 | goderich
# Processing Record 39 of Set 4 | saint-augustin
# Processing Record 40 of Set 4 | guerrero negro
# Processing Record 41 of Set 4 | tiksi
# Processing Record 42 of Set 4 | lasa
# Processing Record 43 of Set 4 | revelstoke
# Processing Record 44 of Set 4 | tingrela
# City not found. Skipping...
# Processing Record 45 of Set 4 | yatou
# Processing Record 46 of Set 4 | katsuura
# Processing Record 47 of Set 4 | nantucket
# Processing Record 48 of Set 4 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 49 of Set 4 | sao joao da barra
# Processing Record 50 of Set 4 | adrar
# Processing Record 1 of Set 5 | rivadavia
# Processing Record 2 of Set 5 | pauini
# Processing Record 3 of Set 5 | nikolskoye
# Processing Record 4 of Set 5 | rawson
# Processing Record 5 of Set 5 | najran
# Processing Record 6 of Set 5 | podebrady
# Processing Record 7 of Set 5 | maracacume
# Processing Record 8 of Set 5 | orotina
# Processing Record 9 of Set 5 | maykain
# City not found. Skipping...
# Processing Record 10 of Set 5 | rungata
# City not found. Skipping...
# Processing Record 11 of Set 5 | tatawin
# Processing Record 12 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 13 of Set 5 | waipawa
# Processing Record 14 of Set 5 | isangel
# Processing Record 15 of Set 5 | yangjiang
# Processing Record 16 of Set 5 | bintulu
# Processing Record 17 of Set 5 | bubaque
# Processing Record 18 of Set 5 | richards bay
# Processing Record 19 of Set 5 | karkaralinsk
# City not found. Skipping...
# Processing Record 20 of Set 5 | moen
# Processing Record 21 of Set 5 | benghazi
# Processing Record 22 of Set 5 | brasilia de minas
# Processing Record 23 of Set 5 | vao
# Processing Record 24 of Set 5 | ponta do sol
# Processing Record 25 of Set 5 | berzunti
# Processing Record 26 of Set 5 | sur
# Processing Record 27 of Set 5 | lakes entrance
# Processing Record 28 of Set 5 | tawang
# Processing Record 29 of Set 5 | barawe
# City not found. Skipping...
# Processing Record 30 of Set 5 | fortuna
# Processing Record 31 of Set 5 | kaoma
# Processing Record 32 of Set 5 | kem
# Processing Record 33 of Set 5 | sao filipe
# Processing Record 34 of Set 5 | ngukurr
# City not found. Skipping...
# Processing Record 35 of Set 5 | vostok
# Processing Record 36 of Set 5 | key west
# Processing Record 37 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 38 of Set 5 | raudeberg
# Processing Record 39 of Set 5 | swanton
# Processing Record 40 of Set 5 | koulamoutou
# Processing Record 41 of Set 5 | harrisonburg
# Processing Record 42 of Set 5 | lodja
# Processing Record 43 of Set 5 | augusto correa
# Processing Record 44 of Set 5 | pacific grove
# Processing Record 45 of Set 5 | kismayo
# Processing Record 46 of Set 5 | havelock
# Processing Record 47 of Set 5 | kieta
# Processing Record 48 of Set 5 | makakilo city
# Processing Record 49 of Set 5 | pontal do parana
# Processing Record 50 of Set 5 | saint george
# Processing Record 1 of Set 6 | port elizabeth
# Processing Record 2 of Set 6 | sioux lookout
# Processing Record 3 of Set 6 | bethel
# Processing Record 4 of Set 6 | laguna
# Processing Record 5 of Set 6 | calama
# Processing Record 6 of Set 6 | hare bay
# Processing Record 7 of Set 6 | palmer
# Processing Record 8 of Set 6 | kendari
# Processing Record 9 of Set 6 | iberia
# Processing Record 10 of Set 6 | thinadhoo
# Processing Record 11 of Set 6 | turukhansk
# Processing Record 12 of Set 6 | salinopolis
# Processing Record 13 of Set 6 | taungdwingyi
# Processing Record 14 of Set 6 | half moon bay
# Processing Record 15 of Set 6 | yirol
# City not found. Skipping...
# Processing Record 16 of Set 6 | barrow
# Processing Record 17 of Set 6 | malindi
# Processing Record 18 of Set 6 | bad kreuznach
# Processing Record 19 of Set 6 | imeni poliny osipenko
# Processing Record 20 of Set 6 | odweyne
# Processing Record 21 of Set 6 | ikalamavony
# Processing Record 22 of Set 6 | poltavka
# Processing Record 23 of Set 6 | livadia
# Processing Record 24 of Set 6 | saskylakh
# Processing Record 25 of Set 6 | alofi
# Processing Record 26 of Set 6 | bodden town
# Processing Record 27 of Set 6 | bengkulu
# Processing Record 28 of Set 6 | codrington
# Processing Record 29 of Set 6 | kaeo
# Processing Record 30 of Set 6 | arroyo
# Processing Record 31 of Set 6 | nanortalik
# Processing Record 32 of Set 6 | lebu
# Processing Record 33 of Set 6 | east london
# Processing Record 34 of Set 6 | soure
# Processing Record 35 of Set 6 | avera
# Processing Record 36 of Set 6 | kerema
# Processing Record 37 of Set 6 | boffa
# Processing Record 38 of Set 6 | pravia
# Processing Record 39 of Set 6 | norman wells
# Processing Record 40 of Set 6 | champoton
# Processing Record 41 of Set 6 | florida
# Processing Record 42 of Set 6 | alugan
# Processing Record 43 of Set 6 | villacidro
# Processing Record 44 of Set 6 | palana
# Processing Record 45 of Set 6 | kattivakkam
# Processing Record 46 of Set 6 | phangnga
# Processing Record 47 of Set 6 | mao
# Processing Record 48 of Set 6 | zarand
# Processing Record 49 of Set 6 | klaksvik
# Processing Record 50 of Set 6 | barroualie
# City not found. Skipping...
# Processing Record 1 of Set 7 | coronado
# Processing Record 2 of Set 7 | bauchi
# Processing Record 3 of Set 7 | nelson bay
# Processing Record 4 of Set 7 | benguela
# Processing Record 5 of Set 7 | sug-aksy
# City not found. Skipping...
# Processing Record 6 of Set 7 | berlevag
# Processing Record 7 of Set 7 | westpunt
# City not found. Skipping...
# Processing Record 8 of Set 7 | ponta delgada
# Processing Record 9 of Set 7 | diego de almagro
# Processing Record 10 of Set 7 | srednekolymsk
# Processing Record 11 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 12 of Set 7 | byron bay
# Processing Record 13 of Set 7 | pangody
# Processing Record 14 of Set 7 | ahuimanu
# Processing Record 15 of Set 7 | souillac
# Processing Record 16 of Set 7 | avanigadda
# Processing Record 17 of Set 7 | nogliki
# Processing Record 18 of Set 7 | aswan
# Processing Record 19 of Set 7 | college
# Processing Record 20 of Set 7 | moron
# Processing Record 21 of Set 7 | hay river
# Processing Record 22 of Set 7 | kirksville
# Processing Record 23 of Set 7 | peniche
# Processing Record 24 of Set 7 | emba
# Processing Record 25 of Set 7 | vrangel
# Processing Record 26 of Set 7 | marsaxlokk
# Processing Record 27 of Set 7 | yulara
# Processing Record 28 of Set 7 | flinders
# Processing Record 29 of Set 7 | aksarka
# Processing Record 30 of Set 7 | boldumsaz
# Processing Record 31 of Set 7 | bambanglipuro
# Processing Record 32 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 33 of Set 7 | west wendover
# Processing Record 34 of Set 7 | coruripe
# Processing Record 35 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 36 of Set 7 | korla
# Processing Record 37 of Set 7 | satitoa
# City not found. Skipping...
# Processing Record 38 of Set 7 | nishihara
# Processing Record 39 of Set 7 | severo-kurilsk
# Processing Record 40 of Set 7 | lerwick
# Processing Record 41 of Set 7 | shimoda
# Processing Record 42 of Set 7 | cabo san lucas
# Processing Record 43 of Set 7 | ouargaye
# Processing Record 44 of Set 7 | agadir
# Processing Record 45 of Set 7 | san carlos de bariloche
# Processing Record 46 of Set 7 | kentau
# Processing Record 47 of Set 7 | coihaique
# Processing Record 48 of Set 7 | dingle
# Processing Record 49 of Set 7 | sandovo
# Processing Record 50 of Set 7 | gemena
# Processing Record 1 of Set 8 | alotau
# City not found. Skipping...
# Processing Record 2 of Set 8 | aklavik
# Processing Record 3 of Set 8 | nongstoin
# Processing Record 4 of Set 8 | cururupu
# Processing Record 5 of Set 8 | kuito
# Processing Record 6 of Set 8 | masuguru
# Processing Record 7 of Set 8 | thaba-tseka
# Processing Record 8 of Set 8 | nome
# Processing Record 9 of Set 8 | santa luzia
# Processing Record 10 of Set 8 | mabaruma
# Processing Record 11 of Set 8 | grand-santi
# Processing Record 12 of Set 8 | meulaboh
# Processing Record 13 of Set 8 | singarayakonda
# Processing Record 14 of Set 8 | jinchang
# Processing Record 15 of Set 8 | cockburn harbour
# City not found. Skipping...
# Processing Record 16 of Set 8 | gasa
# Processing Record 17 of Set 8 | qaqortoq
# Processing Record 18 of Set 8 | muros
# Processing Record 19 of Set 8 | palaikastron
# Processing Record 20 of Set 8 | karauzyak
# City not found. Skipping...
# Processing Record 21 of Set 8 | gat
# Processing Record 22 of Set 8 | louisbourg
# City not found. Skipping...
# Processing Record 23 of Set 8 | leninskoye
# Processing Record 24 of Set 8 | jutai
# Processing Record 25 of Set 8 | udachnyy
# Processing Record 26 of Set 8 | nizhniy kuranakh
# Processing Record 27 of Set 8 | te anau
# Processing Record 28 of Set 8 | north bend
# Processing Record 29 of Set 8 | bridlington
# Processing Record 30 of Set 8 | prince rupert
# Processing Record 31 of Set 8 | port hardy
# Processing Record 32 of Set 8 | campobasso
# Processing Record 33 of Set 8 | mareeba
# Processing Record 34 of Set 8 | tapalpa
# Processing Record 35 of Set 8 | takob
# City not found. Skipping...
# Processing Record 36 of Set 8 | sokoto
# Processing Record 37 of Set 8 | marsh harbour
# Processing Record 38 of Set 8 | la asuncion
# Processing Record 39 of Set 8 | iguape
# Processing Record 40 of Set 8 | ketchikan
# Processing Record 41 of Set 8 | fort nelson
# Processing Record 42 of Set 8 | bhanpura
# Processing Record 43 of Set 8 | kitwe
# Processing Record 44 of Set 8 | colesberg
# Processing Record 45 of Set 8 | enshi
# Processing Record 46 of Set 8 | porto santo
# Processing Record 47 of Set 8 | kavieng
# Processing Record 48 of Set 8 | nemuro
# Processing Record 49 of Set 8 | hami
# Processing Record 50 of Set 8 | juneau
# Processing Record 1 of Set 9 | sladkovo
# Processing Record 2 of Set 9 | port hedland
# Processing Record 3 of Set 9 | sabha
# Processing Record 4 of Set 9 | peremyshlyany
# Processing Record 5 of Set 9 | aguimes
# Processing Record 6 of Set 9 | saurimo
# Processing Record 7 of Set 9 | gergebil
# Processing Record 8 of Set 9 | anaconda
# Processing Record 9 of Set 9 | okitipupa
# Processing Record 10 of Set 9 | ordu
# Processing Record 11 of Set 9 | saleilua
# City not found. Skipping...
# Processing Record 12 of Set 9 | brokopondo
# Processing Record 13 of Set 9 | bolgatanga
# Processing Record 14 of Set 9 | roald
# Processing Record 15 of Set 9 | narasapur
# Processing Record 16 of Set 9 | sungaipenuh
# Processing Record 17 of Set 9 | uhlove
# Processing Record 18 of Set 9 | baoding
# Processing Record 19 of Set 9 | north myrtle beach
# Processing Record 20 of Set 9 | saldanha
# Processing Record 21 of Set 9 | shaunavon
# Processing Record 22 of Set 9 | aksaray
# Processing Record 23 of Set 9 | rocha
# Processing Record 24 of Set 9 | parakou
# Processing Record 25 of Set 9 | champerico
# Processing Record 26 of Set 9 | tehachapi
# Processing Record 27 of Set 9 | santa vitoria do palmar
# Processing Record 28 of Set 9 | maningrida
# Processing Record 29 of Set 9 | san carlos
# Processing Record 30 of Set 9 | saint anthony
# Processing Record 31 of Set 9 | brenham
# Processing Record 32 of Set 9 | luderitz
# Processing Record 33 of Set 9 | impfondo
# Processing Record 34 of Set 9 | caconda
# Processing Record 35 of Set 9 | duma
# Processing Record 36 of Set 9 | bandar
# Processing Record 37 of Set 9 | aksu
# Processing Record 38 of Set 9 | lagos
# Processing Record 39 of Set 9 | oga
# Processing Record 40 of Set 9 | morondava
# Processing Record 41 of Set 9 | aripuana
# Processing Record 42 of Set 9 | sorvag
# City not found. Skipping...
# Processing Record 43 of Set 9 | anadyr
# Processing Record 44 of Set 9 | panino
# Processing Record 45 of Set 9 | onda
# Processing Record 46 of Set 9 | viedma
# Processing Record 47 of Set 9 | tateyama
# Processing Record 48 of Set 9 | lethem
# Processing Record 49 of Set 9 | podgornoye
# Processing Record 50 of Set 9 | wukari
# Processing Record 1 of Set 10 | burnie
# Processing Record 2 of Set 10 | dibaya
# City not found. Skipping...
# Processing Record 3 of Set 10 | miles city
# Processing Record 4 of Set 10 | sarakhs
# Processing Record 5 of Set 10 | makaha
# Processing Record 6 of Set 10 | rehoboth
# Processing Record 7 of Set 10 | itaituba
# Processing Record 8 of Set 10 | cooma
# Processing Record 9 of Set 10 | progreso
# Processing Record 10 of Set 10 | kholmogory
# Processing Record 11 of Set 10 | pisco
# Processing Record 12 of Set 10 | havoysund
# Processing Record 13 of Set 10 | namatanai
# Processing Record 14 of Set 10 | zapolyarnyy
# Processing Record 15 of Set 10 | urumqi
# Processing Record 16 of Set 10 | abu kamal
# Processing Record 17 of Set 10 | geraldton
# Processing Record 18 of Set 10 | vanavara
# Processing Record 19 of Set 10 | samana
# Processing Record 20 of Set 10 | santa lucia
# Processing Record 21 of Set 10 | gravdal
# Processing Record 22 of Set 10 | vilyuysk
# Processing Record 23 of Set 10 | verkh-usugli
# Processing Record 24 of Set 10 | matiri
# Processing Record 25 of Set 10 | sal rei
# Processing Record 26 of Set 10 | khanpur
# Processing Record 27 of Set 10 | boa vista
# Processing Record 28 of Set 10 | beyneu
# Processing Record 29 of Set 10 | esqueda
# Processing Record 30 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 31 of Set 10 | tahe
# Processing Record 32 of Set 10 | maraba
# Processing Record 33 of Set 10 | marondera
# Processing Record 34 of Set 10 | sistranda
# Processing Record 35 of Set 10 | kavaratti
# Processing Record 36 of Set 10 | anton lizardo
# Processing Record 37 of Set 10 | biltine
# Processing Record 38 of Set 10 | broome
# Processing Record 39 of Set 10 | eureka
# Processing Record 40 of Set 10 | grande-riviere
# City not found. Skipping...
# Processing Record 41 of Set 10 | marawi
# Processing Record 42 of Set 10 | necochea
# Processing Record 43 of Set 10 | velyka oleksandrivka
# Processing Record 44 of Set 10 | araioses
# Processing Record 45 of Set 10 | dolores
# Processing Record 46 of Set 10 | oistins
# Processing Record 47 of Set 10 | rajula
# Processing Record 48 of Set 10 | payo
# Processing Record 49 of Set 10 | fare
# Processing Record 50 of Set 10 | kambove
# Processing Record 1 of Set 11 | price
# Processing Record 2 of Set 11 | rorvik
# Processing Record 3 of Set 11 | shahr-e kord
# Processing Record 4 of Set 11 | hambantota
# Processing Record 5 of Set 11 | sancti spiritus
# Processing Record 6 of Set 11 | formosa
# Processing Record 7 of Set 11 | mana
# Processing Record 8 of Set 11 | kiunga
# Processing Record 9 of Set 11 | shenjiamen
# Processing Record 10 of Set 11 | mungwi
# Processing Record 11 of Set 11 | covarachia
# City not found. Skipping...
# Processing Record 12 of Set 11 | pokosnoye
# Processing Record 13 of Set 11 | oranjemund
# Processing Record 14 of Set 11 | shangrao
# Processing Record 15 of Set 11 | ust-omchug
# Processing Record 16 of Set 11 | torbay
# Processing Record 17 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 18 of Set 11 | lompoc
# Processing Record 19 of Set 11 | melville
# Processing Record 20 of Set 11 | padang
# Processing Record 21 of Set 11 | caravelas
# Processing Record 22 of Set 11 | cockburn town
# Processing Record 23 of Set 11 | luanda
# Processing Record 24 of Set 11 | killarney
# Processing Record 25 of Set 11 | lorengau
# Processing Record 26 of Set 11 | bell ville
# Processing Record 27 of Set 11 | grand gaube
# Processing Record 28 of Set 11 | baruun-urt
# Processing Record 29 of Set 11 | kudahuvadhoo
# Processing Record 30 of Set 11 | grand river south east
# City not found. Skipping...
# Processing Record 31 of Set 11 | sao felix do xingu
# Processing Record 32 of Set 11 | nizhniy lomov
# Processing Record 33 of Set 11 | banjar
# Processing Record 34 of Set 11 | karamay
# City not found. Skipping...
# Processing Record 35 of Set 11 | bababe
# City not found. Skipping...
# Processing Record 36 of Set 11 | haimen
# Processing Record 37 of Set 11 | otukpo
# Processing Record 38 of Set 11 | harwich
# Processing Record 39 of Set 11 | dukat
# Processing Record 40 of Set 11 | catamarca
# Processing Record 41 of Set 11 | karaul
# City not found. Skipping...
# Processing Record 42 of Set 11 | blackwater
# Processing Record 43 of Set 11 | rincon
# Processing Record 44 of Set 11 | quang ngai
# Processing Record 45 of Set 11 | uray
# Processing Record 46 of Set 11 | khandyga
# Processing Record 47 of Set 11 | abbeville
# Processing Record 48 of Set 11 | jiayuguan
# Processing Record 49 of Set 11 | ballina
# Processing Record 50 of Set 11 | kuytun
# Processing Record 1 of Set 12 | atagay
# Processing Record 2 of Set 12 | uvira
# Processing Record 3 of Set 12 | san cristobal
# Processing Record 4 of Set 12 | trinidad
# Processing Record 5 of Set 12 | jumla
# Processing Record 6 of Set 12 | toliary
# City not found. Skipping...
# Processing Record 7 of Set 12 | harper
# Processing Record 8 of Set 12 | batman
# Processing Record 9 of Set 12 | micheweni
# Processing Record 10 of Set 12 | masinloc
# Processing Record 11 of Set 12 | kenai
# Processing Record 12 of Set 12 | chepareria
# Processing Record 13 of Set 12 | saint-francois
# Processing Record 14 of Set 12 | hirara
# Processing Record 15 of Set 12 | mandera
# Processing Record 16 of Set 12 | margate
# Processing Record 17 of Set 12 | honningsvag
# Processing Record 18 of Set 12 | sinazongwe
# Processing Record 19 of Set 12 | homer
# Processing Record 20 of Set 12 | cayenne
# Processing Record 21 of Set 12 | touros
# Processing Record 22 of Set 12 | san policarpo
# Processing Record 23 of Set 12 | eskisehir
# Processing Record 24 of Set 12 | muyezerskiy
# Processing Record 25 of Set 12 | angra
# City not found. Skipping...
# Processing Record 26 of Set 12 | muswellbrook
# Processing Record 27 of Set 12 | hualmay
# Processing Record 28 of Set 12 | chuy
# Processing Record 29 of Set 12 | curanilahue
# Processing Record 30 of Set 12 | rock sound
# Processing Record 31 of Set 12 | bowen
# Processing Record 32 of Set 12 | wattegama
# Processing Record 33 of Set 12 | kadoma
# Processing Record 34 of Set 12 | magaria
# Processing Record 35 of Set 12 | opuwo
# Processing Record 36 of Set 12 | grindavik
# Processing Record 37 of Set 12 | mendoza
# Processing Record 38 of Set 12 | inirida
# Processing Record 39 of Set 12 | phalaborwa
# Processing Record 40 of Set 12 | talnakh
# Processing Record 41 of Set 12 | laiyang
# Processing Record 42 of Set 12 | pipri
# Processing Record 43 of Set 12 | santa ana
# Processing Record 44 of Set 12 | chaiya
# Processing Record 45 of Set 12 | wundanyi
# Processing Record 46 of Set 12 | ippy
# Processing Record 47 of Set 12 | kununurra
# Processing Record 48 of Set 12 | bastia
# Processing Record 49 of Set 12 | miraflores
# Processing Record 50 of Set 12 | san felipe
# Processing Record 1 of Set 13 | huarmey
# Processing Record 2 of Set 13 | male
# Processing Record 3 of Set 13 | nanchang
# Processing Record 4 of Set 13 | kewanee
# Processing Record 5 of Set 13 | gold coast
# Processing Record 6 of Set 13 | aflu
# City not found. Skipping...
# Processing Record 7 of Set 13 | namangan
# Processing Record 8 of Set 13 | pousat
# City not found. Skipping...
# Processing Record 9 of Set 13 | waynesboro
# Processing Record 10 of Set 13 | husavik
# Processing Record 11 of Set 13 | yeppoon
# Processing Record 12 of Set 13 | tarudant
# City not found. Skipping...
# Processing Record 13 of Set 13 | wamba
# Processing Record 14 of Set 13 | serebryansk
# Processing Record 15 of Set 13 | nushki
# Processing Record 16 of Set 13 | angoram
# Processing Record 17 of Set 13 | loiza
# Processing Record 18 of Set 13 | shulan
# Processing Record 19 of Set 13 | vaitape
# Processing Record 20 of Set 13 | jibuti
# Processing Record 21 of Set 13 | goulburn
# Processing Record 22 of Set 13 | zhirnov
# Processing Record 23 of Set 13 | luancheng
# Processing Record 24 of Set 13 | cortes
# Processing Record 25 of Set 13 | halalo
# City not found. Skipping...
# Processing Record 26 of Set 13 | farah
# Processing Record 27 of Set 13 | nagato
# Processing Record 28 of Set 13 | gardiner
# Processing Record 29 of Set 13 | obluche
# City not found. Skipping...
# Processing Record 30 of Set 13 | do rud
# City not found. Skipping...
# Processing Record 31 of Set 13 | tabiauea
# City not found. Skipping...
# Processing Record 32 of Set 13 | sangar
# Processing Record 33 of Set 13 | myitkyina
# Processing Record 34 of Set 13 | japura
# Processing Record 35 of Set 13 | altamont
# Processing Record 36 of Set 13 | kongolo
# Processing Record 37 of Set 13 | jinka
# Processing Record 38 of Set 13 | iracoubo
# Processing Record 39 of Set 13 | tevaitoa
# Processing Record 40 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 41 of Set 13 | buenos aires
# Processing Record 42 of Set 13 | sorong
# Processing Record 43 of Set 13 | olga
# Processing Record 44 of Set 13 | grand-couronne
# Processing Record 45 of Set 13 | eyl
# Processing Record 46 of Set 13 | port said
# Processing Record 47 of Set 13 | saint-georges
# Processing Record 48 of Set 13 | miramar
# Processing Record 49 of Set 13 | komsomolskiy
# Processing Record 50 of Set 13 | pangnirtung
# Processing Record 1 of Set 14 | yazman
# Processing Record 2 of Set 14 | katobu
# Processing Record 3 of Set 14 | kegayli
# City not found. Skipping...
# Processing Record 4 of Set 14 | tromso
# Processing Record 5 of Set 14 | tarko-sale
# Processing Record 6 of Set 14 | galesong
# Processing Record 7 of Set 14 | walvis bay
# Processing Record 8 of Set 14 | erenhot
# Processing Record 9 of Set 14 | omutinskoye
# City not found. Skipping...
# Processing Record 10 of Set 14 | belaya gora
# Processing Record 11 of Set 14 | bilibino
# Processing Record 12 of Set 14 | tocopilla
# Processing Record 13 of Set 14 | mont-de-marsan
# Processing Record 14 of Set 14 | tupik
# Processing Record 15 of Set 14 | the valley
# Processing Record 16 of Set 14 | sergeyevka
# Processing Record 17 of Set 14 | humen
# Processing Record 18 of Set 14 | bosaso
# Processing Record 19 of Set 14 | san andres
# Processing Record 20 of Set 14 | sitio novo do tocantins
# Processing Record 21 of Set 14 | gushikawa
# Processing Record 22 of Set 14 | lagoa
# Processing Record 23 of Set 14 | saint-denis
# Processing Record 24 of Set 14 | nioro
# Processing Record 25 of Set 14 | charagua
# Processing Record 26 of Set 14 | maragogi
# Processing Record 27 of Set 14 | bundaberg
# Processing Record 28 of Set 14 | dalby
# Processing Record 29 of Set 14 | mahajanga
# Processing Record 30 of Set 14 | sobolevo
# Processing Record 31 of Set 14 | kimle
# Processing Record 32 of Set 14 | sindou
# Processing Record 33 of Set 14 | rosarito
# Processing Record 34 of Set 14 | tasbuget
# City not found. Skipping...
# Processing Record 35 of Set 14 | mercedes
# Processing Record 36 of Set 14 | prince george
# Processing Record 37 of Set 14 | vila
# Processing Record 38 of Set 14 | uzhur
# Processing Record 39 of Set 14 | skibbereen
# Processing Record 40 of Set 14 | utiroa
# City not found. Skipping...
# Processing Record 41 of Set 14 | bafata
# Processing Record 42 of Set 14 | plettenberg bay
# Processing Record 43 of Set 14 | kosai
# Processing Record 44 of Set 14 | durres
# Processing Record 45 of Set 14 | santa rosa
# Processing Record 46 of Set 14 | oyama
# Processing Record 47 of Set 14 | yanan
# City not found. Skipping...
# Processing Record 48 of Set 14 | seoul
# Processing Record 49 of Set 14 | karratha
# Processing Record 50 of Set 14 | minsk
# Processing Record 1 of Set 15 | great yarmouth
# Processing Record 2 of Set 15 | tornio
# Processing Record 3 of Set 15 | izazi
# Processing Record 4 of Set 15 | leningradskiy
# Processing Record 5 of Set 15 | arman
# Processing Record 6 of Set 15 | eydhafushi
# Processing Record 7 of Set 15 | la joya
# Processing Record 8 of Set 15 | melilla
# Processing Record 9 of Set 15 | talara
# Processing Record 10 of Set 15 | bumba
# Processing Record 11 of Set 15 | coahuayana
# Processing Record 12 of Set 15 | clyde river
# Processing Record 13 of Set 15 | borogontsy
# Processing Record 14 of Set 15 | turayf
# Processing Record 15 of Set 15 | ola
# Processing Record 16 of Set 15 | alta floresta
# Processing Record 17 of Set 15 | gillette
# Processing Record 18 of Set 15 | singkang
# Processing Record 19 of Set 15 | evensk
# Processing Record 20 of Set 15 | maine-soroa
# Processing Record 21 of Set 15 | abalak
# Processing Record 22 of Set 15 | rudbar
# Processing Record 23 of Set 15 | araouane
# Processing Record 24 of Set 15 | severnyy
# Processing Record 25 of Set 15 | uglegorsk
# Processing Record 26 of Set 15 | kulhudhuffushi
# Processing Record 27 of Set 15 | janow lubelski
# Processing Record 28 of Set 15 | milton
# Processing Record 29 of Set 15 | beidao
# Processing Record 30 of Set 15 | parana
# Processing Record 31 of Set 15 | orsta
# Processing Record 32 of Set 15 | angoche
# Processing Record 33 of Set 15 | zhuhai
# Processing Record 34 of Set 15 | linqing
# Processing Record 35 of Set 15 | norrtalje
# Processing Record 36 of Set 15 | mount darwin
# Processing Record 37 of Set 15 | beberibe
# Processing Record 38 of Set 15 | manggar
# Processing Record 39 of Set 15 | nichinan
# Processing Record 40 of Set 15 | cabra
# Processing Record 41 of Set 15 | haibowan
# City not found. Skipping...
# Processing Record 42 of Set 15 | dehloran
# Processing Record 43 of Set 15 | viking
# Processing Record 44 of Set 15 | miyako
# Processing Record 45 of Set 15 | elat
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 680

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0         Auki  -8.7676  160.7034     80.58        79         100        1.45
# 1       Hobart -42.8794  147.3294     53.02        76          75        1.01
# 2  Port Alfred -33.5906   26.8910     64.29        76         100        7.25
# 3   Chokurdakh  70.6333  147.9167    -20.33        94         100       13.38
# 4      Rikitea -23.1203 -134.9692     76.59        74          64       14.32
# 5   Vila Velha -20.3297  -40.2925     75.15        95          90        5.01
# 6   Den Helder  52.9599    4.7593     46.38        96          75        8.01
# 7  New Norfolk -42.7826  147.0587     52.66        67          98        5.01
# 8        Airai  -8.9266  125.4092     61.00        88          86        3.13
# 9       Albany  42.6001  -73.9662     36.81        50           2        1.01
#
#   Country                 Date Course Description
# 0      SB  2021-12-03 20:45:43    overcast clouds
# 1      AU  2021-12-03 20:45:44      broken clouds
# 2      ZA  2021-12-03 20:44:36    overcast clouds
# 3      RU  2021-12-03 20:45:44    overcast clouds
# 4      PF  2021-12-03 20:44:20         light rain
# 5      BR  2021-12-03 20:45:45               mist
# 6      NL  2021-12-03 20:45:46      broken clouds
# 7      AU  2021-12-03 20:44:22    overcast clouds
# 8      TL  2021-12-03 20:45:46    overcast clouds
# 9      US  2021-12-03 20:41:28          clear sky

# %%
column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness","Wind Speed","Course Description" ]
city_data_df = city_data_df[column_order]
city_data_df.head(10)
# Out:
#           City Country                 Date      Lat       Lng  Max Temp  \
# 0         Auki      SB  2021-12-03 20:45:43  -8.7676  160.7034     80.58
# 1       Hobart      AU  2021-12-03 20:45:44 -42.8794  147.3294     53.02
# 2  Port Alfred      ZA  2021-12-03 20:44:36 -33.5906   26.8910     64.29
# 3   Chokurdakh      RU  2021-12-03 20:45:44  70.6333  147.9167    -20.33
# 4      Rikitea      PF  2021-12-03 20:44:20 -23.1203 -134.9692     76.59
# 5   Vila Velha      BR  2021-12-03 20:45:45 -20.3297  -40.2925     75.15
# 6   Den Helder      NL  2021-12-03 20:45:46  52.9599    4.7593     46.38
# 7  New Norfolk      AU  2021-12-03 20:44:22 -42.7826  147.0587     52.66
# 8        Airai      TL  2021-12-03 20:45:46  -8.9266  125.4092     61.00
# 9       Albany      US  2021-12-03 20:41:28  42.6001  -73.9662     36.81
#
#    Humidity  Cloudiness  Wind Speed Course Description
# 0        79         100        1.45    overcast clouds
# 1        76          75        1.01      broken clouds
# 2        76         100        7.25    overcast clouds
# 3        94         100       13.38    overcast clouds
# 4        74          64       14.32         light rain
# 5        95          90        5.01               mist
# 6        96          75        8.01      broken clouds
# 7        67          98        5.01    overcast clouds
# 8        88          86        3.13    overcast clouds
# 9        50           2        1.01          clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
